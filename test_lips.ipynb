# %%
# Test LIPS dans Codespace
import numpy as np
import matplotlib.pyplot as plt
from lips.dataset.airfransDataSet import download_data, AirfRANSDataSet

# Configuration
DIRECTORY_NAME = 'Dataset'

# Test de téléchargement (petit échantillon pour commencer)
print("🚀 Test LIPS dans Codespace")
print("=" * 40)

# Vérifier les imports
try:
    from lips.benchmark.airfransBenchmark import AirfRANSBenchmark
    print("✅ Benchmark importé")
    
    from lips.augmented_simulators.torch_simulator import TorchSimulator
    print("✅ Simulateurs PyTorch importés")
    
    print("\n🎉 LIPS prêt pour vos expérimentations!")
    
except ImportError as e:
    print(f"❌ Erreur: {e}")

# Prochaine étape : télécharger les données
print("\n📁 Prochaine étape : télécharger le dataset AirfRANS")
print("⚠️ Note : le téléchargement peut prendre plusieurs minutes")
# Out:
# 🚀 Test LIPS dans Codespace
# ...
# ✅ Benchmark importé
# ✅ Simulateurs PyTorch importés
#
# 🎉 LIPS prêt pour vos expérimentations!
#
# 📁 Prochaine étape : télécharger le dataset AirfRANS
# ⚠️ Note : le téléchargement peut prendre plusieurs minutes
